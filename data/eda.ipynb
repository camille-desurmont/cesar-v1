# %%
import pandas as pd
import sklearn
import fastapi
print("All good")
# Out:
# All good

# %%
import sys, pandas as pd
print(sys.executable)
print(pd.__version__)
# Out:
# c:\Users\USER\Documents\GitHub\cesar-v1\.venv\Scripts\python.exe
# 3.0.1

# %%
import pandas as pd

mlopsdata = pd.read_csv('C:/Users/USER/Documents/GitHub/cesar-v1/data/dvf_75115_000CM.csv', sep=';')
mlopsdata.head()
# Out:
#     id_mutation date_mutation  numero_disposition nature_mutation  \
# 0   2025-500599    2025-03-28                   1           Vente
# 1   2025-500599    2025-03-28                   1           Vente
# 2  2023-1355458    2023-10-11                   1           Vente
# 3  2023-1355458    2023-10-11                   1           Vente
# 4  2023-1355670    2023-10-09                   1           Vente
#
#    valeur_fonciere  adresse_numero  adresse_suffixe adresse_nom_voie  \
# 0         620100.0              22              NaN   RUE ANDRE GIDE
# 1         620100.0              22              NaN   RUE ANDRE GIDE
# 2         490000.0              22              NaN   RUE ANDRE GIDE
# 3         490000.0              22              NaN   RUE ANDRE GIDE
# 4          20000.0              22              NaN   RUE ANDRE GIDE
#
#   adresse_code_voie  code_postal  ...  surface_reelle_bati  \
# 0              0324        75015  ...                 67.0
# ...
